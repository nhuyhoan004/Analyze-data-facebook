# %% [markdown]
# # Thư viện

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import json
import re
import datetime
# %matplotlib inline

# %%
df = pd.read_csv('Data/LordsMobileVN.csv')

# %%
df_clean = pd.read_csv('Data/LordsMobileVN.csv')

# %%
df_clean
# Out:
#              post_id                                               text  \
# 0    752698296898984  Sự hợp tác hoành tráng giữa Lords Mobile x Arm...
# 1    744907481011399            🥹 Không có so sánh, không có đau thương
# 2    745522664283214  Hồi xưa thấy bình thường ha, giờ thì quý lắm l...
# 3    752111686957645                                                NaN
# 4    751732603662220  🎁 THỬ THÁCH GIẢI ĐỐ 7 NGÀY 6 ĐÊM GÉT GÔ 🎁\r\n▪...
# ..               ...                                                ...
# 195  688423049993176            Mời các nông dân vườn khoai trả lời ạ !
# 196  686334866868661  Sau bao nhiêu năm, người đàn ông tôi cần nhất ...
# 197  687518510083630  🧑‍⚕️ Nào mình cùng đến thăm bệnh nhân tại Thán...
# 198  687500140085467  Chào tháng 8 cùng nhiều sự kiện hấp dẫn diễn r...
# 199  683580670477414     😎 Bận bộ full cham cam auto đẹp nha các Boss !
#
#                                              post_text  shared_text  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 53 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   post_id                        200 non-null    int64
#  1   text                           194 non-null    object
#  2   post_text                      194 non-null    object
#  3   shared_text                    0 non-null      float64
#  4   original_text                  15 non-null     object
#  5   time                           200 non-null    object
#  6   timestamp                      190 non-null    float64
#  7   image                          174 non-null    object
#  8   image_lowquality               200 non-null    object
#  9   images                         200 non-null    object
#  10  images_description             200 non-null    object
#  11  images_lowquality              200 non-null    object
# ...

# %%
df['reactions'].unique()
# Out:
# array(["{'like': 54, 'love': 4, 'haha': 1}", "{'like': 97, 'haha': 25}",
#        "{'like': 130, 'love': 3, 'haha': 30, 'wow': 1, 'sad': 1}",
#        "{'like': 91, 'love': 2, 'haha': 6}", "{'like': 96, 'love': 2}",
#        "{'like': 156, 'love': 3, 'haha': 27, 'wow': 1, 'care': 3, 'angry': 1}",
#        "{'like': 79, 'love': 2, 'haha': 45, 'care': 1}",
#        "{'like': 79, 'love': 3}",
#        "{'like': 132, 'love': 2, 'haha': 91, 'wow': 1}",
#        "{'like': 124, 'love': 2, 'haha': 1}", "{'like': 51, 'love': 1}",
#        "{'like': 95, 'love': 4, 'haha': 1, 'care': 1}",
#        "{'like': 82, 'love': 1}", "{'like': 71, 'love': 1}",
#        "{'like': 185, 'love': 2, 'haha': 122, 'sad': 3}",
#        "{'like': 126, 'love': 5, 'haha': 1}",
#        "{'like': 220, 'love': 4, 'haha': 178, 'sad': 2}",
#        "{'like': 97, 'love': 2}", "{'like': 87, 'wow': 1}",
#        "{'like': 116, 'love': 5, 'haha': 35, 'care': 1, 'sad': 2, 'angry': 1}",
#        "{'like': 164, 'love': 5}",
# ...

# %%
df_clean
# Out:
#              post_id                                               text  \
# 0    752698296898984  Sự hợp tác hoành tráng giữa Lords Mobile x Arm...
# 1    744907481011399            🥹 Không có so sánh, không có đau thương
# 2    745522664283214  Hồi xưa thấy bình thường ha, giờ thì quý lắm l...
# 3    752111686957645                                                NaN
# 4    751732603662220  🎁 THỬ THÁCH GIẢI ĐỐ 7 NGÀY 6 ĐÊM GÉT GÔ 🎁\r\n▪...
# ..               ...                                                ...
# 195  688423049993176            Mời các nông dân vườn khoai trả lời ạ !
# 196  686334866868661  Sau bao nhiêu năm, người đàn ông tôi cần nhất ...
# 197  687518510083630  🧑‍⚕️ Nào mình cùng đến thăm bệnh nhân tại Thán...
# 198  687500140085467  Chào tháng 8 cùng nhiều sự kiện hấp dẫn diễn r...
# 199  683580670477414     😎 Bận bộ full cham cam auto đẹp nha các Boss !
#
#                                              post_text  shared_text  \
# ...

# %%
df_clean['reactions'] = df['reactions'].apply(lambda x : dict(eval(x)) )
df_clean['reactions'] = df['reactions'].apply(pd.Series )
# Out:
# C:\Users\nhuyh\AppData\Local\Temp\ipykernel_19288\3898460851.py:2: FutureWarning: Returning a DataFrame from Series.apply when the supplied function returns a Series is deprecated and will be removed in a future version.
#   df_clean['reactions'] = df['reactions'].apply(pd.Series )

# %%
df_clean['reactions']
# Out:
# 0                     {'like': 54, 'love': 4, 'haha': 1}
# 1                               {'like': 97, 'haha': 25}
# 2      {'like': 130, 'love': 3, 'haha': 30, 'wow': 1,...
# 3                     {'like': 91, 'love': 2, 'haha': 6}
# 4                                {'like': 96, 'love': 2}
#                              ...
# 195    {'like': 183, 'love': 2, 'haha': 44, 'wow': 2,...
# 196       {'like': 96, 'love': 3, 'haha': 27, 'care': 1}
# 197    {'like': 176, 'love': 3, 'haha': 164, 'wow': 2...
# 198                  {'like': 132, 'love': 7, 'haha': 1}
# 199    {'like': 247, 'love': 2, 'haha': 70, 'care': 1...
# Name: reactions, Length: 200, dtype: object

# %%
df_clean['reactions'] = df_clean['reactions'].fillna(0)

# %%
# Chuyển kiểu dữ liệu của fetched_time sang datetime64
df_clean['time'] = pd.to_datetime(df['time'])
df_clean['time']
# Out:
# 0     2023-11-14 16:29:00
# 1     2023-11-14 08:00:00
# 2     2023-11-13 16:00:00
# 3     2023-11-13 10:23:14
# 4     2023-11-13 10:00:03
#               ...
# 195   2023-08-04 11:14:35
# 196   2023-08-04 08:00:01
# 197   2023-08-03 16:00:02
# 198   2023-08-03 08:00:01
# 199   2023-08-02 08:00:02
# Name: time, Length: 200, dtype: datetime64[ns]

# %%
df_clean = df.drop(["timestamp","shared_text","original_text","factcheck",
                    "shared_post_id","shared_time","shared_user_id","shared_username",
                    "shared_post_url","video_ids","text","image","image_lowquality","images","images_description",
                    "images_lowquality","images_lowquality_description","video",
                    "video_duration_seconds","video_height","video_quality",
                    "video_size_MB","video_thumbnail","video_watches","video_width",
                    "post_url","links","user_id","username","user_url","available","w3_fb_url",
                    "with","page_id","sharers","image_ids","videos","was_live","fetched_time"], axis=1)

# %%
# thêm index cho dataframe
df_clean = df_clean.reset_index(inplace = False)
df_clean["index"] = df_clean["index"] + 1

# %%
df['image_id'].fillna(0, inplace = True)
df['video_id'].fillna(0, inplace = True)

# %%
df_clean['Has_image'] = df['image_id'].astype(bool)
df_clean['Has_video'] = df['video_id'].astype(bool)

# %%
df_clean
# Out:
#      index          post_id  \
# 0        1  752698296898984
# 1        2  744907481011399
# 2        3  745522664283214
# 3        4  752111686957645
# 4        5  751732603662220
# ..     ...              ...
# 195    196  688423049993176
# 196    197  686334866868661
# 197    198  687518510083630
# 198    199  687500140085467
# 199    200  683580670477414
#
#                                              post_text                 time  \
# 0    Sự hợp tác hoành tráng giữa Lords Mobile x Arm...  2023-11-14 16:29:00
# 1              🥹 Không có so sánh, không có đau thương  2023-11-14 08:00:00
# 2    Hồi xưa thấy bình thường ha, giờ thì quý lắm l...  2023-11-13 16:00:00
# 3                                                  NaN  2023-11-13 10:23:14
# 4    🎁 THỬ THÁCH GIẢI ĐỐ 7 NGÀY 6 ĐÊM GÉT GÔ 🎁\r\n▪...  2023-11-13 10:00:03
# ..                                                 ...                  ...
# 195            Mời các nông dân vườn khoai trả lời ạ !  2023-08-04 11:14:35
# ...

# %%
df_clean.to_csv('Data/LordsMobileVN_clean.csv', index=False)
